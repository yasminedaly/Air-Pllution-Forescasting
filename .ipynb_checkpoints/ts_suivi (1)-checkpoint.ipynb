# %%
install.packages("zoo")

install.packages("xts")
library(xts)

library(ggplot2)
library(lubridate)
library(zoo)
library(xts)
# Out:
#   There is a binary version available but the source version is later:
#     binary source needs_compilation
# zoo  1.8-9 1.8-12              TRUE
#
#   Binaries will be installed
# package 'zoo' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'zoo'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\Yasmine Daly\.conda\envs\r-tutorial\Lib\R\library\00LOCK\zoo\libs\x64\zoo.dll to C:\Users\Yasmine Daly\.conda\envs\r-tutorial\Lib\R\library\zoo\libs\x64\zoo.dll: Permission denied"Warning message:
# "restored 'zoo'"
# The downloaded binary packages are in
# 	C:\Users\Yasmine Daly\AppData\Local\Temp\RtmpiuTKfl\downloaded_packages
#
#   There is a binary version available but the source version is later:
#     binary source needs_compilation
# xts 0.12.1 0.13.1              TRUE
#
#   Binaries will be installed
# package 'xts' successfully unpacked and MD5 sums checked
# Warning message:
# ...

# %%
##Data Importation
file_name="LSTM-Multivariate_pollution.csv"
data <- read.csv(file_name,header=T)
#Checking size of data column in the dataset
length(data$date)
# Out:
# [1] 43800

# %%
show(data)
# Out:
#                      date pollution dew temp    press wnd_dir wnd_spd snow rain
# 1     2010-01-02 00:00:00       129 -16   -4 1020.000      SE    1.79    0    0
# 2     2010-01-02 01:00:00       148 -15   -4 1020.000      SE    2.68    0    0
# 3     2010-01-02 02:00:00       159 -11   -5 1021.000      SE    3.57    0    0
# 4     2010-01-02 03:00:00       181  -7   -5 1022.000      SE    5.36    1    0
# 5     2010-01-02 04:00:00       138  -7   -5 1022.000      SE    6.25    2    0
# 6     2010-01-02 05:00:00       109  -7   -6 1022.000      SE    7.14    3    0
# 7     2010-01-02 06:00:00       105  -7   -6 1023.000      SE    8.93    4    0
# 8     2010-01-02 07:00:00       124  -7   -5 1024.000      SE   10.72    0    0
# 9     2010-01-02 08:00:00       120  -8   -6 1024.000      SE   12.51    0    0
# 10    2010-01-02 09:00:00       132  -7   -5 1025.000      SE   14.30    0    0
# 11    2010-01-02 10:00:00       140  -7   -5 1026.000      SE   17.43    1    0
# ...

# %%
#Date
data$date <- as.POSIXct(data$date, format = "%Y-%m-%d %H:%M:%S",by="hour")

# %%
data_ts <- zoo(data$pollution, order.by = data$date,frequency=24)

head(data_ts)
# Out:
# 2010-01-02 00:00:00 2010-01-02 01:00:00 2010-01-02 02:00:00 2010-01-02 03:00:00
#                 129                 148                 159                 181
# 2010-01-02 04:00:00 2010-01-02 05:00:00
#                 138                 109

# %%
#acf(data_ts , lag=24)

# %%
#pacf(ts_data , lag=7)

# %%
ts_data <- ts(data_ts, frequency = 24)

# %%
decomp_ts <- decompose(ts_data)

# %%
multiplicative.decomposition<-decompose(ts_data,type=c("additive"))
plot(multiplicative.decomposition)
# Out:
# plot without title

# %%
daily_ts <- aggregate(ts_data, FUN = mean)

# %%
ts_daily <- ts(daily_ts, frequency = 7)

# %%
multiplicative.decomposition<-decompose(ts_daily)
plot(multiplicative.decomposition)
# Out:
# plot without title

# %%
weekly_ts <- aggregate(daily_ts, FUN = mean)

length(weekly_ts)
# Out:
# [1] 1825

# %%
ts_weekly <- ts(weekly_ts, frequency = 7)

pacf(ts_daily , lag=7)
# Out:
# Plot with title "Series  ts_daily"

# %%
length(ts_daily)
# Out:
# [1] 1825

# %%
plot(ts_daily)
# Out:
# plot without title

# %%
multiplicative.decomposition<-decompose(ts_daily)
plot(multiplicative.decomposition)
# Out:
# plot without title

# %%
Time<-c(1:length(ts_daily))
model1<-lm(ts_daily~Time)
summary(model1)
# Out:
# Call:
# lm(formula = ts_daily ~ Time)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -94.38 -56.25 -19.73  32.92 435.05
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 92.134563   3.622588  25.433   <2e-16 ***
# Time         0.002058   0.003437   0.599    0.549
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 77.35 on 1823 degrees of freedom
# Multiple R-squared:  0.0001967,	Adjusted R-squared:  -0.0003518
# F-statistic: 0.3586 on 1 and 1823 DF,  p-value: 0.5494

# %%
plot(ts_daily,lwd=2)
points(time(ts_daily),fitted(model1),col="orange2",lwd=2,type="l")
# Out:
# plot without title

# %%
model2<-lm(ts_daily~Time+I(Time^2))
#help(I)
summary(model2)
# Out:
# Call:
# lm(formula = ts_daily ~ Time + I(Time^2))
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -95.82 -56.30 -19.71  32.62 433.64
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  8.887e+01  5.438e+00  16.342   <2e-16 ***
# Time         1.278e-02  1.376e-02   0.929    0.353
# I(Time^2)   -5.872e-06  7.294e-06  -0.805    0.421
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 77.35 on 1822 degrees of freedom
# Multiple R-squared:  0.0005522,	Adjusted R-squared:  -0.0005449
# F-statistic: 0.5033 on 2 and 1822 DF,  p-value: 0.6046

# %%
plot(ts_daily,lwd=2)
points(time(ts_daily),fitted(model1),col=2,lwd=2,type="l")
points(time(ts_daily),fitted(model2),col=3,lwd=2,type="l")
# Out:
# plot without title

# %%
T=7
MC=matrix(0,length(ts_daily),6)
MS=matrix(0,length(ts_daily),6)
for (i in 1:(T/2)){MC[,i]=cos(2*pi*i*Time/T)}
for (i in 1:(T/2)){MS[,i]=sin(2*pi*i*Time/T)}

# %%
model3<-lm(ts_daily~Time+MC+MS)
summary(model3)
# Out:
# Call:
# lm(formula = ts_daily ~ Time + MC + MS)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -98.57 -56.43 -20.62  32.81 429.51
#
# Coefficients: (6 not defined because of singularities)
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 92.130199   3.625296  25.413   <2e-16 ***
# Time         0.002064   0.003439   0.600    0.548
# MC1          3.846564   2.562963   1.501    0.134
# MC2         -0.805994   2.562485  -0.315    0.753
# MC3         -0.142699   2.563559  -0.056    0.956
# MC4                NA         NA      NA       NA
# MC5                NA         NA      NA       NA
# MC6                NA         NA      NA       NA
# MS1          0.937205   2.561873   0.366    0.715
# MS2          2.268101   2.562346   0.885    0.376
# MS3         -0.273776   2.561274  -0.107    0.915
# MS4                NA         NA      NA       NA
# MS5                NA         NA      NA       NA
# MS6                NA         NA      NA       NA
# ---
# ...

# %%
model4<-lm(ts_daily~Time+I(Time^2)+MC+MS)
summary(model4)
# Out:
# Call:
# lm(formula = ts_daily ~ Time + I(Time^2) + MC + MS)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -98.90 -56.43 -20.12  32.98 428.10
#
# Coefficients: (6 not defined because of singularities)
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  8.887e+01  5.442e+00  16.330   <2e-16 ***
# Time         1.276e-02  1.377e-02   0.927    0.354
# I(Time^2)   -5.858e-06  7.299e-06  -0.803    0.422
# MC1          3.841e+00  2.563e+00   1.498    0.134
# MC2         -8.088e-01  2.563e+00  -0.316    0.752
# MC3         -1.431e-01  2.564e+00  -0.056    0.956
# MC4                 NA         NA      NA       NA
# MC5                 NA         NA      NA       NA
# MC6                 NA         NA      NA       NA
# MS1          9.400e-01  2.562e+00   0.367    0.714
# MS2          2.272e+00  2.563e+00   0.886    0.375
# MS3         -2.722e-01  2.562e+00  -0.106    0.915
# MS4                 NA         NA      NA       NA
# ...

# %%
model5<-lm(log(ts_daily)~Time+I(Time^2)+MC+MS)
summary(model5)
# Out:
# Error in lm.fit(x, y, offset = offset, singular.ok = singular.ok, ...): NA/NaN/Inf in 'y'
# Traceback:
#
# 1. lm(log(ts_daily) ~ Time + I(Time^2) + MC + MS)
# 2. lm.fit(x, y, offset = offset, singular.ok = singular.ok, ...)

# %%
plot(ts_daily,lwd=2)
#points(time(AP),fitted(model1),col=2,lwd=2,type="l")
#points(time(AP),fitted(model2),col=3,lwd=2,type="l")
#points(time(AP),fitted(model3),col="blue3",lwd=2,type="l")
points(time(ts_daily),fitted(model3),col="red",lwd=2,type="l")
points(time(ts_daily),fitted(model4),col="pink2",lwd=2,type="l")
#points(time(ts_daily),exp(fitted(model5)),col="orange2",lwd=2,type="l")

# %%
AIC(model3)
AIC(model4)

# %%
BIC(model3)
BIC(model4)

# %%
# Models of the document 

t<-c(1:length(ts_daily))
s.t<-(t-mean(t))/sd(t) # this variable is introduced in order to guarantee

# %%
CS<-matrix(0,length(ts_daily),6)
SN<-matrix(0,length(ts_daily),6)
for (i in 1:3) CS[,i]<-cos(2*pi*i*t/12)
for (i in 1:3) SN[,i]<-sin(2*pi*i*t/12)

# %%
Model1<-lm(ts_daily~s.t+CS+SN)

summary(Model1)

# %%
Model2<-lm(ts_daily~s.t+I(s.t^2)+CS+SN)

summary(Model2)

# %%
# comaprison of Model 1 and Model2

plot(ts_daily,lwd=2)
points(time(ts_daily),fitted(Model1),col=2,lwd=2,type="l")
points(time(ts_daily),fitted(Model2),col=3,lwd=2,type="l")

# %%
sp.res<-Model2$residuals
plot(time(ts_daily),sp.res, xlab="Time", ylab="",
 main="Residual component",
 col="purple4",lwd=2,type="l")

# %%
library(tseries)
adf.test(sp.res)

# %%
acf(sp.res)
Box.test(sp.res)

# %%
acf(sp.res,50)
pacf(sp.res,50)

# %%
# our best model is  ARIMA (0 , 1 , 3)

Model.res<-arima(sp.res,order = c(1, 0, 1))
adf.test(Model.res$residuals)
checkresiduals(Model.res)

# %%
d.sp.ts.24<-diff(sp.res,24,1)
acf(d.sp.ts.24,50)
pacf(d.sp.ts.24,50)

# %%
arima(sp.res, order = c(1, 1, 2),seasonal = list(order = c(0,1,2), period=7))
#arima(sp.res, order = c(1, 1, 2),seasonal = list(order = c(1,1,2), period=24)
#arima(sp.res, order = c(1, 1, 2),seasonal = list(order = c(2,1,0), period=24)
#arima(sp.res, order = c(1, 1, 2),seasonal = list(order = c(2,1,1), period=24)
